# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/DDOS/22-03-2024-3h/tp_rw.csv")

# %%
df.plot(x="Time", y="database")
plt.xlabel('Time')
plt.ylabel('BW out')
plt.title('SQL inj. attack bandwidth')
plt.xticks([])
plt.show()
