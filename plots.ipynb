# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv("./output/BruteForce/17-04-2024-11h/data1.csv")
df2 = pd.read_csv("./output/BruteForce/17-04-2024-11h/data2.csv")
attack_name = "BruteForce (17-04)"
attack_abv = 'bf'
save_directory1 = "./output/BruteForce/17-04-2024-11h/plots1/"
save_directory2 = "./output/BruteForce/17-04-2024-11h/plots2/"

# df = df.sort_values(by='timestamp')
df1 = df1.drop(df1.index[:5])

# %% [markdown]
# Method 1

# %%
df1.plot(x="timestamp", y="cpu")
plt.xlabel('Time')
plt.ylabel('CPU')
plt.title(attack_name + ' attack (CPU/Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_cpu_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y="class")
plt.xlabel('Time')
plt.ylabel('Malicious flows')
plt.title(attack_name + ' attack (Malicious flows/Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_class_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y="flow_duration")
plt.xlabel('Time')
plt.ylabel('Flow duration')
plt.title(attack_name + ' attack (Flow duration/Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_flow_duration_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y="flow_byts_s")
plt.xlabel('Time')
plt.ylabel('Flow Bytes/s')
plt.title(attack_name + ' attack (Flow Bytes/s /Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_flow_byts_s_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y="flow_pkts_s")
plt.xlabel('Time')
plt.ylabel('Flow Packets/s')
plt.title(attack_name + ' attack (Flow Packets/s /Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_flow_pkts_s_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y=["tot_fwd_pkts", "tot_bwd_pkts"])
plt.xlabel('Time')
plt.ylabel('Total packets')
plt.title(attack_name + ' attack (Total packets/Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_tot_pkts_time.png")
plt.show()

# %%
df1.plot(x="timestamp", y=["totlen_fwd_pkts", "totlen_bwd_pkts"])
plt.xlabel('Time')
plt.ylabel('Total length of packets')
plt.title(attack_name + ' attack (Total length of packets/Time)')
plt.xticks([])
plt.savefig(save_directory1 + attack_abv + "_totlen_pkts_time.png")
plt.show()

# %% [markdown]
# Method 2

# %%
df2.plot(x="timestamp", y="cpu_total")
plt.xlabel('Time')
plt.ylabel('CPU')
plt.title(attack_name + ' attack (CPU/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_cpu_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y="num_flows")
plt.xlabel('Time')
plt.ylabel('Number of flows')
plt.title(attack_name + ' attack (Number of flows/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_num_flows_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y="class")
plt.xlabel('Time')
plt.ylabel('Malicious flows')
plt.title(attack_name + ' attack (Malicious flows/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_class_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y="flow_duration")
plt.xlabel('Time')
plt.ylabel('Flow duration')
plt.title(attack_name + ' attack (Flow duration/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_flow_duration_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y="flow_byts_s")
plt.xlabel('Time')
plt.ylabel('Flow Bytes/s')
plt.title(attack_name + ' attack (Flow Bytes/s /Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_flow_byts_s_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y="flow_pkts_s")
plt.xlabel('Time')
plt.ylabel('Flow Packets/s')
plt.title(attack_name + ' attack (Flow Packets/s /Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_flow_pkts_s_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y=["tot_fwd_pkts", "tot_bwd_pkts"])
plt.xlabel('Time')
plt.ylabel('Total packets')
plt.title(attack_name + ' attack (Total packets/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_tot_pkts_time.png")
plt.show()

# %%
df2.plot(x="timestamp", y=["totlen_fwd_pkts", "totlen_bwd_pkts"])
plt.xlabel('Time')
plt.ylabel('Total length of packets')
plt.title(attack_name + ' attack (Total length of packets/Time)')
plt.xticks([])
plt.savefig(save_directory2 + attack_abv + "_totlen_pkts_time.png")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("./output/DOS/16-02/flows.csv")
print(df.shape)
# Out:
# (145391, 80)
